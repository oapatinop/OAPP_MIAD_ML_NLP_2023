# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Construcción e implementación de modelos Bagging, Random Forest y XGBoost
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de modelos de Bagging, Random Forest y XGBoost. El taller está constituido por 8 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción precio de automóviles
#
# En este taller se usará el conjunto de datos de Car Listings de Kaggle donde cada observación representa el precio de un automóvil teniendo en cuenta distintas variables como año, marca, modelo, entre otras. El objetivo es predecir el precio del automóvil. Para más detalles puede visitar el siguiente enlace: [datos](https://www.kaggle.com/jpayne/852k-used-car-listings).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
# %matplotlib inline
import pandas as pd
import numpy as np

# Lectura de la información de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/dataTrain_carListings.zip')

# Preprocesamiento de datos para el taller
data = data.loc[data['Model'].str.contains('Camry')].drop(['Make', 'State'], axis=1)
data = data.join(pd.get_dummies(data['Model'], prefix='M'))
data = data.drop(['Model'], axis=1)

# Visualización dataset
data.head()
# Out:
#      Price  Year  Mileage  M_Camry  M_Camry4dr  M_CamryBase  M_CamryL  \
# 7    21995  2014     6480        0           0            0         1
# 11   13995  2014    39972        0           0            0         0
# 167  17941  2016    18989        0           0            0         0
# 225  12493  2014    51330        0           0            0         1
# 270   7994  2007   116065        0           1            0         0
#
#      M_CamryLE  M_CamrySE  M_CamryXLE
# 7            0          0           0
# 11           1          0           0
# 167          0          1           0
# 225          0          0           0
# 270          0          0           0

# %%
# Separación de variables predictoras (X) y variable de interés (y)
y = data['Price']
X = data.drop(['Price'], axis=1)

# %%
# Separación de datos en set de entrenamiento y test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Punto 1 - Árbol de decisión manual
#
# En la celda 1 creen un árbol de decisión **manualmente**  que considere los set de entrenamiento y test definidos anteriormente y presenten el RMSE y MAE del modelo en el set de test.

# %%
# Celda 1
def best_split(X, y, num_pct=10):
    features = range(X.shape[1])
    best_split = [0, 0, 0]  # j, split, mse
    # Para todas las varibles 
    for j in features:
        splits = np.percentile(X.iloc[:, j], np.arange(0, 100, 100.0 / (num_pct+1)).tolist())
        splits = np.unique(splits)[1:]
        
        # Para cada partición
        i=0
        for split in splits:
            filter_l = X.iloc[:,j] < split
            y_l = y.loc[filter_l]
            y_r = y.loc[~filter_l]
            mse = np.average(np.square(y_l.mean()-y))
            if i==0:
                best_split = [j, split, mse]
            elif (mse < best_split[2]):
                best_split = [j, split, mse]
            i+=1
    
    return best_split

def tree_grow(X, y, level=0, max_depth=None, num_pct=10):
    
    # Si solo es una observación
    if X.shape[0] == 1:
        tree = dict(y_pred=y.iloc[:1].values[0], y_prob=y.mean(), level=level, split=-1, n_samples=1,mse=0)
        return tree
    
    # Calcular la mejor división
    j, split, mse = best_split(X, y, num_pct)
    
    # Guardar el árbol y estimar la predicción
    y_pred = int(y.mean()) 
    y_prob = (y.sum()+1) / (y.shape[0]+2)  # Corrección Laplace 
    
    tree = dict(y_pred=y_pred, y_prob=y_prob, level=level, split=-1, n_samples=X.shape[0],mse=mse)
    # Revisar el criterio de parada 
    if max_depth is not None:
        if level >= max_depth:
            return tree   
    
    # Continuar creando la partición
    filter_l = X.iloc[:, j] < split
    X_l, y_l = X.loc[filter_l], y.loc[filter_l]
    X_r, y_r = X.loc[~filter_l], y.loc[~filter_l]
    tree['split'] = [j, split]

    # Siguiente iteración para cada partición
    
    tree['sl'] = tree_grow(X_l, y_l, level + 1, max_depth=max_depth, num_pct=num_pct)
    tree['sr'] = tree_grow(X_r, y_r, level + 1, max_depth=max_depth, num_pct=num_pct)
    
    return tree

def tree_predict(X, tree, proba=False):
    
    predicted = np.ones(X.shape[0])

    # Revisar si es el nodo final
    if tree['split'] == -1:
        if not proba:
            predicted = predicted * tree['y_pred']
        else:
            predicted = predicted * tree['y_prob']
            
    else:
        
        j, split = tree['split']
        filter_l = (X.iloc[:, j] < split)
        X_l = X.loc[filter_l]
        X_r = X.loc[~filter_l]

        if X_l.shape[0] == 0:  # Si el nodo izquierdo está vacio solo continua con el derecho 
            predicted[~filter_l] = tree_predict(X_r, tree['sr'], proba)
        elif X_r.shape[0] == 0:  #  Si el nodo derecho está vacio solo continua con el izquierdo
            predicted[filter_l] = tree_predict(X_l, tree['sl'], proba)
        else:
            predicted[filter_l] = tree_predict(X_l, tree['sl'], proba)
            predicted[~filter_l] = tree_predict(X_r, tree['sr'], proba)

    return predicted

# %%
tree = tree_grow(X_train, y_train, level=0, max_depth=10, num_pct=10)
tree
# Out:
# {'y_pred': 14508,
#  'y_prob': 14503.947817432107,
#  'level': 0,
#  'split': [8, 1.0],
#  'n_samples': 7031,
#  'mse': 15508537.05335372,
#  'sl': {'y_pred': 14217,
#   'y_prob': 14213.416559897501,
#   'level': 1,
#   'split': [7, 1.0],
#   'n_samples': 6242,
#   'mse': 16676597.5695051,
#   'sl': {'y_pred': 12795,
#    'y_prob': 12788.057340720221,
#    'level': 2,
#    'split': [6, 1.0],
#    'n_samples': 3608,
#    'mse': 18241215.662586488,
#    'sl': {'y_pred': 11201,
#     'y_prob': 11190.313827032625,
#     'level': 3,
#     'split': [5, 1.0],
#     'n_samples': 1929,
#     'mse': 14085927.385804303,
#     'sl': {'y_pred': 10479,
#      'y_prob': 10466.337913803873,
#      'level': 4,
#      'split': [3, 1.0],
#      'n_samples': 1599,
#      'mse': 15237857.756493198,
#      'sl': {'y_pred': 12127,
#       'y_prob': 12077.959514170041,
#       'level': 5,
#       'split': [4, 1.0],
#       'n_samples': 492,
#       'mse': 22536756.14931653,
#       'sl': {'y_pred': 12734,
#        'y_prob': 12671.718137254902,
#        'level': 6,
#        'split': [1, 131225.0],
#        'n_samples': 406,
#        'mse': 24295802.110905003,
#        'sl': {'y_pred': 13295,
#         'y_prob': 13224.018867924528,
#         'level': 7,
#         'split': [1, 114710.54545454547],
#         'n_samples': 369,
#         'mse': 22967920.949344505,
#         'sl': {'y_pred': 13822,
#          'y_prob': 13740.741839762612,
#          'level': 8,
#          'split': [1, 102773.36363636366],
#          'n_samples': 335,
#          'mse': 21998013.947554436,
#          'sl': {'y_pred': 14399,
#           'y_prob': 14305.339869281046,
#           'level': 9,
#           'split': [1, 94892.81818181819],
#           'n_samples': 304,
#           'mse': 20205683.22151368,
#           'sl': {'y_pred': 14969,
#            'y_prob': 14861.510791366907,
#            'level': 10,
#            'split': -1,
#            'n_samples': 276,
#            'mse': 18131203.268048827},
#           'sr': {'y_pred': 8783,
#            'y_prob': 8197.833333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 28,
#            'mse': 4346584.230742858}},
#          'sr': {'y_pred': 8167,
#           'y_prob': 7672.636363636364,
#           'level': 9,
#           'split': [1, 107436.63636363637],
#           'n_samples': 31,
#           'mse': 3924606.2625293,
#           'sl': {'y_pred': 8219,
#            'y_prob': 7354.263157894737,
#            'level': 10,
#            'split': -1,
#            'n_samples': 17,
#            'mse': 4029091.2287581693},
#           'sr': {'y_pred': 8104,
#            'y_prob': 7091.6875,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'mse': 3855386.041322314}}},
#         'sr': {'y_pred': 8102,
#          'y_prob': 7652.277777777777,
#          'level': 8,
#          'split': [1, 128707.0],
#          'n_samples': 34,
#          'mse': 3080307.092027758,
#          'sl': {'y_pred': 8148,
#           'y_prob': 7586.862068965517,
#           'level': 9,
#           'split': [1, 127972.0],
#           'n_samples': 27,
#           'mse': 2803566.9477237654,
#           'sl': {'y_pred': 8294,
#            'y_prob': 7656.7692307692305,
#            'level': 10,
#            'split': -1,
#            'n_samples': 24,
#            'mse': 2750723.1096938774},
#           'sr': {'y_pred': 6981,
#            'y_prob': 4188.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 2179945.6666666665}},
#          'sr': {'y_pred': 7923,
#           'y_prob': 6162.666666666667,
#           'level': 9,
#           'split': [1, 130949.72727272728],
#           'n_samples': 7,
#           'mse': 4243687.678571428,
#           'sl': {'y_pred': 8177,
#            'y_prob': 6133.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 4437052.206666667},
#           'sr': {'y_pred': 6398,
#            'y_prob': 6398.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}},
#        'sr': {'y_pred': 7133,
#         'y_prob': 6767.974358974359,
#         'level': 7,
#         'split': [1, 172411.8181818182],
#         'n_samples': 37,
#         'mse': 2344587.0696398877,
#         'sl': {'y_pred': 7199,
#          'y_prob': 6788.114285714286,
#          'level': 8,
#          'split': [1, 139220.54545454544],
#          'n_samples': 33,
#          'mse': 2505709.0830527497,
#          'sl': {'y_pred': 7291,
#           'y_prob': 5965.909090909091,
#           'level': 9,
#           'split': [1, 137327.45454545456],
#           'n_samples': 9,
#           'mse': 2174389.4444444445,
#           'sl': {'y_pred': 7353,
#            'y_prob': 5882.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'mse': 2426322.25},
#           'sr': {'y_pred': 6800,
#            'y_prob': 6800.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 7164,
#           'y_prob': 6613.846153846154,
#           'level': 9,
#           'split': [1, 166665.36363636365],
#           'n_samples': 24,
#           'mse': 2649354.575680272,
#           'sl': {'y_pred': 7349,
#            'y_prob': 6710.347826086957,
#            'level': 10,
#            'split': -1,
#            'n_samples': 21,
#            'mse': 2673018.960295475},
#           'sr': {'y_pred': 5874,
#            'y_prob': 3524.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 309825.0}}},
#         'sr': {'y_pred': 6591,
#          'y_prob': 4394.666666666667,
#          'level': 8,
#          'split': [1, 193105.54545454544],
#          'n_samples': 4,
#          'mse': 733370.1944444443,
#          'sl': {'y_pred': 6459,
#           'y_prob': 3876.0,
#           'level': 9,
#           'split': [1, 179818.63636363635],
#           'n_samples': 3,
#           'mse': 885188.25,
#           'sl': {'y_pred': 6439,
#            'y_prob': 3220.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 2651904.5},
#           'sr': {'y_pred': 6500,
#            'y_prob': 6500.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 6988,
#           'y_prob': 6988.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}},
#       'sr': {'y_pred': 9261,
#        'y_prob': 9050.59090909091,
#        'level': 6,
#        'split': [1, 143958.63636363635],
#        'n_samples': 86,
#        'mse': 3719877.769911166,
#        'sl': {'y_pred': 9508,
#         'y_prob': 9270.4125,
#         'level': 7,
#         'split': [1, 127061.0],
#         'n_samples': 78,
#         'mse': 3249081.400020931,
#         'sl': {'y_pred': 9719,
#          'y_prob': 9449.930555555555,
#          'level': 8,
#          'split': [1, 113916.0],
#          'n_samples': 70,
#          'mse': 3095691.686621315,
#          'sl': {'y_pred': 9875,
#           'y_prob': 9571.215384615385,
#           'level': 9,
#           'split': [1, 111465.0],
#           'n_samples': 63,
#           'mse': 3068503.361078134,
#           'sl': {'y_pred': 10016,
#            'y_prob': 9677.22033898305,
#            'level': 10,
#            'split': -1,
#            'n_samples': 57,
#            'mse': 2958959.308201299},
#           'sr': {'y_pred': 8528,
#            'y_prob': 6396.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 2124864.1458333335}},
#          'sr': {'y_pred': 8323,
#           'y_prob': 6474.111111111111,
#           'level': 9,
#           'split': [1, 118886.63636363637],
#           'n_samples': 7,
#           'mse': 1114551.2685714285,
#           'sl': {'y_pred': 8315,
#            'y_prob': 5939.571428571428,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 600659.85},
#           'sr': {'y_pred': 8345,
#            'y_prob': 4172.75,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 4829832.0}}},
#         'sr': {'y_pred': 7654,
#          'y_prob': 6123.9,
#          'level': 8,
#          'split': [1, 143252.27272727274],
#          'n_samples': 8,
#          'mse': 536923.8265306122,
#          'sl': {'y_pred': 7652,
#           'y_prob': 5952.0,
#           'level': 9,
#           'split': [1, 131689.72727272726],
#           'n_samples': 7,
#           'mse': 613676.0634920634,
#           'sl': {'y_pred': 7662,
#            'y_prob': 4597.6,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 389284.25},
#           'sr': {'y_pred': 7645,
#            'y_prob': 5096.833333333333,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'mse': 807926.5}},
#          'sr': {'y_pred': 7671,
#           'y_prob': 7671.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}},
#        'sr': {'y_pred': 6852,
#         'y_prob': 5482.0,
#         'level': 7,
#         'split': [1, 148011.0909090909],
#         'n_samples': 8,
#         'mse': 1694698.625,
#         'sl': {'y_pred': 6848,
#          'y_prob': 4109.0,
#          'level': 8,
#          'split': [1, 147307.45454545456],
#          'n_samples': 3,
#          'mse': 2507666.9166666665,
#          'sl': {'y_pred': 7274,
#           'y_prob': 3637.5,
#           'level': 9,
#           'split': [1, 144581.9090909091],
#           'n_samples': 2,
#           'mse': 5885880.5,
#           'sl': {'y_pred': 8990,
#            'y_prob': 8990.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 5559,
#            'y_prob': 5559.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 5995,
#           'y_prob': 5995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}},
#         'sr': {'y_pred': 6855,
#          'y_prob': 4896.571428571428,
#          'level': 8,
#          'split': [1, 167720.45454545456],
#          'n_samples': 5,
#          'mse': 1321635.0,
#          'sl': {'y_pred': 6930,
#           'y_prob': 4158.2,
#           'level': 9,
#           'split': [1, 163185.0],
#           'n_samples': 3,
#           'mse': 2357006.25,
#           'sl': {'y_pred': 7397,
#            'y_prob': 3699.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 5104012.5},
#           'sr': {'y_pred': 5995,
#            'y_prob': 5995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 6742,
#           'y_prob': 3371.5,
#           'level': 9,
#           'split': [1, 172840.27272727274],
#           'n_samples': 2,
#           'mse': 122512.5,
#           'sl': {'y_pred': 6990,
#            'y_prob': 6990.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 6495,
#            'y_prob': 6495.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}}}},
#      'sr': {'y_pred': 9747,
#       'y_prob': 9729.572587917042,
#       'level': 5,
#       'split': [1, 146143.63636363638],
#       'n_samples': 1107,
#       'mse': 6575634.515283165,
#       'sl': {'y_pred': 10033,
#        'y_prob': 10013.388888888889,
#        'level': 6,
#        'split': [1, 128273.0],
#        'n_samples': 1006,
#        'mse': 6154440.855791315,
#        'sl': {'y_pred': 10275,
#         'y_prob': 10252.657205240175,
#         'level': 7,
#         'split': [1, 117393.0],
#         'n_samples': 914,
#         'mse': 5913926.789942455,
#         'sl': {'y_pred': 10516,
#          'y_prob': 10491.155048076924,
#          'level': 8,
#          'split': [1, 109974.63636363637],
#          'n_samples': 830,
#          'mse': 5623564.698816729,
#          'sl': {'y_pred': 10707,
#           'y_prob': 10678.789682539682,
#           'level': 9,
#           'split': [1, 103000.45454545456],
#           'n_samples': 754,
#           'mse': 5520767.007285889,
#           'sl': {'y_pred': 10882,
#            'y_prob': 10851.001455604075,
#            'level': 10,
#            'split': -1,
#            'n_samples': 685,
#            'mse': 5419613.3066075},
#           'sr': {'y_pred': 8964,
#            'y_prob': 8711.661971830987,
#            'level': 10,
#            'split': -1,
#            'n_samples': 69,
#            'mse': 3028570.167891124}},
#          'sr': {'y_pred': 8624,
#           'y_prob': 8403.551282051281,
#           'level': 9,
#           'split': [1, 116286.27272727274],
#           'n_samples': 76,
#           'mse': 2612723.1039076624,
#           'sl': {'y_pred': 8622,
#            'y_prob': 8353.125,
#            'level': 10,
#            'split': -1,
#            'n_samples': 62,
#            'mse': 2591926.744696773},
#           'sr': {'y_pred': 8634,
#            'y_prob': 7554.875,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'mse': 2705756.6696428573}}},
#         'sr': {'y_pred': 7890,
#          'y_prob': 7706.906976744186,
#          'level': 8,
#          'split': [1, 127007.81818181818],
#          'n_samples': 84,
#          'mse': 2252897.405454425,
#          'sl': {'y_pred': 7972,
#           'y_prob': 7768.115384615385,
#           'level': 9,
#           'split': [1, 125835.54545454546],
#           'n_samples': 76,
#           'mse': 2123121.2257597367,
#           'sl': {'y_pred': 7984,
#            'y_prob': 7759.56338028169,
#            'level': 10,
#            'split': -1,
#            'n_samples': 69,
#            'mse': 2106604.368294651},
#           'sr': {'y_pred': 7854,
#            'y_prob': 6109.444444444444,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 2308704.276785714}},
#          'sr': {'y_pred': 7110,
#           'y_prob': 5688.2,
#           'level': 9,
#           'split': [1, 128089.09090909091],
#           'n_samples': 8,
#           'mse': 2744333.323979592,
#           'sl': {'y_pred': 7140,
#            'y_prob': 5554.111111111111,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 3223757.285714286},
#           'sr': {'y_pred': 6895,
#            'y_prob': 6895.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}},
#        'sr': {'y_pred': 7631,
#         'y_prob': 7468.755319148936,
#         'level': 7,
#         'split': [1, 136213.63636363635],
#         'n_samples': 92,
#         'mse': 2132671.1721391305,
#         'sl': {'y_pred': 7658,
#          'y_prob': 7363.9807692307695,
#          'level': 8,
#          'split': [1, 134736.9090909091],
#          'n_samples': 50,
#          'mse': 2095108.850707912,
#          'sl': {'y_pred': 7665,
#           'y_prob': 7309.232558139535,
#           'level': 9,
#           'split': [1, 133908.27272727274],
#           'n_samples': 41,
#           'mse': 2416831.243724278,
#           'sl': {'y_pred': 7670,
#            'y_prob': 7277.538461538462,
#            'level': 10,
#            'split': -1,
#            'n_samples': 37,
#            'mse': 2579058.8333108113},
#           'sr': {'y_pred': 7618,
#            'y_prob': 5079.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'mse': 929153.25}},
#          'sr': {'y_pred': 7625,
#           'y_prob': 6239.181818181818,
#           'level': 9,
#           'split': [1, 136066.36363636365],
#           'n_samples': 9,
#           'mse': 630064.0,
#           'sl': {'y_pred': 7580,
#            'y_prob': 6064.1,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'mse': 688485.5},
#           'sr': {'y_pred': 7990,
#            'y_prob': 7990.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 7598,
#          'y_prob': 7253.113636363636,
#          'level': 8,
#          'split': [1, 144830.0909090909],
#          'n_samples': 42,
#          'mse': 2176780.954128743,
#          'sl': {'y_pred': 7652,
#           'y_prob': 7270.05,
#           'level': 9,
#           'split': [1, 142913.45454545456],
#           'n_samples': 38,
#           'mse': 2317287.6000273176,
#           'sl': {'y_pred': 7669,
#            'y_prob': 7243.277777777777,
#            'level': 10,
#            'split': -1,
#            'n_samples': 34,
#            'mse': 2542800.022352941},
#           'sr': {'y_pred': 7511,
#            'y_prob': 5007.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'mse': 426482.0}},
#          'sr': {'y_pred': 7083,
#           'y_prob': 4722.666666666667,
#           'level': 9,
#           'split': [1, 145087.18181818182],
#           'n_samples': 4,
#           'mse': 529005.25,
#           'sl': {'y_pred': 6994,
#            'y_prob': 6994.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 7113,
#            'y_prob': 4268.4,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 1003874.0}}}}},
#       'sr': {'y_pred': 6897,
#        'y_prob': 6763.116504854369,
#        'level': 6,
#        'split': [1, 188750.63636363635],
#        'n_samples': 101,
#        'mse': 1517276.5285352897,
#        'sl': {'y_pred': 6911,
#         'y_prob': 6747.047619047619,
#         'level': 7,
#         'split': [1, 175732.45454545456],
#         'n_samples': 82,
#         'mse': 1499612.590470167,
#         'sl': {'y_pred': 6924,
#          'y_prob': 6742.328947368421,
#          'level': 8,
#          'split': [1, 168871.27272727274],
#          'n_samples': 74,
#          'mse': 1425274.294648179,
#          'sl': {'y_pred': 6968,
#           'y_prob': 6766.594202898551,
#           'level': 9,
#           'split': [1, 166570.0],
#           'n_samples': 67,
#           'mse': 1545682.0422388061,
#           'sl': {'y_pred': 7102,
#            'y_prob': 6873.596774193548,
#            'level': 10,
#            'split': -1,
#            'n_samples': 60,
#            'mse': 1491039.7975308641},
#           'sr': {'y_pred': 5818,
#            'y_prob': 4525.888888888889,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 368684.53571428574}},
#          'sr': {'y_pred': 6503,
#           'y_prob': 5058.111111111111,
#           'level': 9,
#           'split': [1, 173843.54545454544],
#           'n_samples': 7,
#           'mse': 228397.78857142854,
#           'sl': {'y_pred': 6506,
#            'y_prob': 4647.714285714285,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 219442.6},
#           'sr': {'y_pred': 6494,
#            'y_prob': 3247.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 509040.5}}},
#         'sr': {'y_pred': 6791,
#          'y_prob': 5433.6,
#          'level': 8,
#          'split': [1, 178240.63636363635],
#          'n_samples': 8,
#          'mse': 2206397.486111111,
#          'sl': {'y_pred': 6654,
#           'y_prob': 3993.0,
#           'level': 9,
#           'split': [1, 176176.27272727274],
#           'n_samples': 3,
#           'mse': 2287720.6666666665,
#           'sl': {'y_pred': 5944,
#            'y_prob': 5944.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 7010,
#            'y_prob': 3505.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 4590450.0}},
#          'sr': {'y_pred': 6874,
#           'y_prob': 4910.285714285715,
#           'level': 9,
#           'split': [1, 184491.81818181818],
#           'n_samples': 5,
#           'mse': 2691696.3625,
#           'sl': {'y_pred': 6345,
#            'y_prob': 4230.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'mse': 2132502.027777778},
#           'sr': {'y_pred': 8988,
#            'y_prob': 8988.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}},
#        'sr': {'y_pred': 6834,
#         'y_prob': 6183.333333333333,
#         'level': 7,
#         'split': [1, 208668.63636363635],
#         'n_samples': 19,
#         'mse': 1591345.489400585,
#         'sl': {'y_pred': 6889,
#          'y_prob': 5905.714285714285,
#          'level': 8,
#          'split': [1, 198960.0],
#          'n_samples': 12,
#          'mse': 1221319.25,
#          'sl': {'y_pred': 6928,
#           'y_prob': 5773.416666666667,
#           'level': 9,
#           'split': [1, 190656.9090909091],
#           'n_samples': 10,
#           'mse': 1437338.6625,
#           'sl': {'y_pred': 6939,
#            'y_prob': 4626.666666666667,
#            'level': 10,
#            'split': -1,
#            'n_samples': 4,
#            'mse': 1426145.25},
#           'sr': {'y_pred': 6920,
#            'y_prob': 5190.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 1515920.0599999998}},
#          'sr': {'y_pred': 6699,
#           'y_prob': 3350.0,
#           'level': 9,
#           'split': [1, 199709.54545454544],
#           'n_samples': 2,
#           'mse': 179400.5,
#           'sl': {'y_pred': 6400,
#            'y_prob': 6400.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 6999,
#            'y_prob': 6999.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 6738,
#          'y_prob': 5241.222222222223,
#          'level': 8,
#          'split': [1, 230637.0909090909],
#          'n_samples': 7,
#          'mse': 2209130.6825396824,
#          'sl': {'y_pred': 6676,
#           'y_prob': 5007.375,
#           'level': 9,
#           'split': [1, 228807.54545454544],
#           'n_samples': 6,
#           'mse': 2650833.7600000002,
#           'sl': {'y_pred': 7000,
#            'y_prob': 5000.571428571428,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 2489413.45},
#           'sr': {'y_pred': 5055,
#            'y_prob': 5055.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 7112,
#           'y_prob': 7112.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}}}},
#     'sr': {'y_pred': 14702,
#      'y_prob': 14614.126506024097,
#      'level': 4,
#      'split': [1, 73524.54545454546],
#      'n_samples': 330,
#      'mse': 3869599.34318788,
#      'sl': {'y_pred': 14920,
#       'y_prob': 14821.705298013245,
#       'level': 5,
#       'split': [1, 58566.727272727294],
#       'n_samples': 300,
#       'mse': 3130022.594950079,
#       'sl': {'y_pred': 15117,
#        'y_prob': 15007.043795620439,
#        'level': 6,
#        'split': [1, 51529.454545454544],
#        'n_samples': 272,
#        'mse': 2712840.402039827,
#        'sl': {'y_pred': 15232,
#         'y_prob': 15110.522088353413,
#         'level': 7,
#         'split': [1, 45422.545454545456],
#         'n_samples': 247,
#         'mse': 2619463.0342980563,
#         'sl': {'y_pred': 15347,
#          'y_prob': 15212.163716814159,
#          'level': 8,
#          'split': [1, 43059.27272727273],
#          'n_samples': 224,
#          'mse': 2643413.2040816327,
#          'sl': {'y_pred': 15392,
#           'y_prob': 15241.980487804878,
#           'level': 9,
#           'split': [1, 34642.454545454544],
#           'n_samples': 203,
#           'mse': 2686391.972545404,
#           'sl': {'y_pred': 15454,
#            'y_prob': 15218.664122137405,
#            'level': 10,
#            'split': -1,
#            'n_samples': 129,
#            'mse': 2560667.689922481},
#           'sr': {'y_pred': 15283,
#            'y_prob': 14881.078947368422,
#            'level': 10,
#            'split': -1,
#            'n_samples': 74,
#            'mse': 2876984.644346842}},
#          'sr': {'y_pred': 14921,
#           'y_prob': 13623.652173913044,
#           'level': 9,
#           'split': [1, 45080.90909090909],
#           'n_samples': 21,
#           'mse': 2044234.9717715343,
#           'sl': {'y_pred': 14942,
#            'y_prob': 13519.380952380952,
#            'level': 10,
#            'split': -1,
#            'n_samples': 19,
#            'mse': 2148469.210526316},
#           'sr': {'y_pred': 14718,
#            'y_prob': 7359.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 2560584.5}}},
#         'sr': {'y_pred': 14111,
#          'y_prob': 12982.88,
#          'level': 8,
#          'split': [1, 47927.0],
#          'n_samples': 23,
#          'mse': 879445.0708695654,
#          'sl': {'y_pred': 14161,
#           'y_prob': 11801.0,
#           'level': 9,
#           'split': [1, 46363.63636363636],
#           'n_samples': 10,
#           'mse': 1569985.7444444448,
#           'sl': {'y_pred': 14081,
#            'y_prob': 8449.2,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 1475751.5833333333},
#           'sr': {'y_pred': 14195,
#            'y_prob': 11040.777777777777,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 1727468.7896825394}},
#          'sr': {'y_pred': 14073,
#           'y_prob': 12197.4,
#           'level': 9,
#           'split': [1, 51106.72727272727],
#           'n_samples': 13,
#           'mse': 348639.4176732358,
#           'sl': {'y_pred': 14017,
#            'y_prob': 11861.307692307691,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'mse': 394709.18545454537},
#           'sr': {'y_pred': 14382,
#            'y_prob': 7191.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 338.0}}}},
#        'sr': {'y_pred': 13976,
#         'y_prob': 12941.148148148148,
#         'level': 7,
#         'split': [1, 57427.36363636364],
#         'n_samples': 25,
#         'mse': 2187611.7237190083,
#         'sl': {'y_pred': 13974,
#          'y_prob': 12809.916666666666,
#          'level': 8,
#          'split': [1, 54964.63636363636],
#          'n_samples': 22,
#          'mse': 2397000.3277698862,
#          'sl': {'y_pred': 13921,
#           'y_prob': 12375.111111111111,
#           'level': 9,
#           'split': [1, 54794.181818181816],
#           'n_samples': 16,
#           'mse': 2803376.7971938774,
#           'sl': {'y_pred': 13855,
#            'y_prob': 12123.9375,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'mse': 3145505.015873016},
#           'sr': {'y_pred': 14384,
#            'y_prob': 7192.5,
#            'level': 10,
#            'split': -1,
#            'n_samples': 2,
#            'mse': 308112.5}},
#          'sr': {'y_pred': 14114,
#           'y_prob': 10585.875,
#           'level': 9,
#           'split': [1, 56766.27272727273],
#           'n_samples': 6,
#           'mse': 1318980.8399999996,
#           'sl': {'y_pred': 13938,
#            'y_prob': 9956.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 1624842.8},
#           'sr': {'y_pred': 14995,
#            'y_prob': 14995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 13991,
#          'y_prob': 8394.8,
#          'level': 8,
#          'split': [1, 57939.181818181816],
#          'n_samples': 3,
#          'mse': 672010.6666666666,
#          'sl': {'y_pred': 13991,
#           'y_prob': 6995.75,
#           'level': 9,
#           'split': [1, 57507.545454545456],
#           'n_samples': 2,
#           'mse': 2016032.0,
#           'sl': {'y_pred': 12987,
#            'y_prob': 12987.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 14995,
#            'y_prob': 14995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 13991,
#           'y_prob': 13991.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}},
#       'sr': {'y_pred': 13008,
#        'y_prob': 12140.866666666667,
#        'level': 6,
#        'split': [1, 59678.0],
#        'n_samples': 28,
#        'mse': 2862862.6071428573,
#        'sl': {'y_pred': 13012,
#         'y_prob': 7807.4,
#         'level': 7,
#         'split': [1, 58767.818181818184],
#         'n_samples': 3,
#         'mse': 2599533.6666666665,
#         'sl': {'y_pred': 12995,
#          'y_prob': 12995.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 13020,
#          'y_prob': 6510.5,
#          'level': 8,
#          'split': [1, 59314.818181818184],
#          'n_samples': 2,
#          'mse': 7797300.5,
#          'sl': {'y_pred': 14995,
#           'y_prob': 14995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 11046,
#           'y_prob': 11046.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}},
#        'sr': {'y_pred': 13007,
#         'y_prob': 12044.074074074075,
#         'level': 7,
#         'split': [1, 72429.0],
#         'n_samples': 25,
#         'mse': 2947747.3649586774,
#         'sl': {'y_pred': 13238,
#          'y_prob': 12135.208333333334,
#          'level': 8,
#          'split': [1, 71792.54545454546],
#          'n_samples': 22,
#          'mse': 2839710.340909091,
#          'sl': {'y_pred': 13386,
#           'y_prob': 12169.59090909091,
#           'level': 9,
#           'split': [1, 62213.63636363636],
#           'n_samples': 20,
#           'mse': 2765990.2,
#           'sl': {'y_pred': 13406,
#            'y_prob': 10054.625,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 4918204.84},
#           'sr': {'y_pred': 13378,
#            'y_prob': 11705.9375,
#            'level': 10,
#            'split': -1,
#            'n_samples': 14,
#            'mse': 1881102.5442739078}},
#          'sr': {'y_pred': 11757,
#           'y_prob': 5878.75,
#           'level': 9,
#           'split': [1, 72194.27272727272],
#           'n_samples': 2,
#           'mse': 1850888.0,
#           'sl': {'y_pred': 12719,
#            'y_prob': 12719.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 10795,
#            'y_prob': 10795.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 11315,
#          'y_prob': 6789.2,
#          'level': 8,
#          'split': [1, 73411.81818181818],
#          'n_samples': 3,
#          'mse': 226422.91666666666,
#          'sl': {'y_pred': 11472,
#           'y_prob': 5736.5,
#           'level': 9,
#           'split': [1, 72531.90909090909],
#           'n_samples': 2,
#           'mse': 456012.5,
#           'sl': {'y_pred': 11950,
#            'y_prob': 11950.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 10995,
#            'y_prob': 10995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 11000,
#           'y_prob': 11000.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}}},
#      'sr': {'y_pred': 12524,
#       'y_prob': 11741.75,
#       'level': 5,
#       'split': [1, 118149.81818181822],
#       'n_samples': 30,
#       'mse': 6076625.936762688,
#       'sl': {'y_pred': 12930,
#        'y_prob': 12038.448275862069,
#        'level': 6,
#        'split': [1, 99084.72727272731],
#        'n_samples': 27,
#        'mse': 4945571.509452161,
#        'sl': {'y_pred': 13287,
#         'y_prob': 12265.153846153846,
#         'level': 7,
#         'split': [1, 92160.81818181818],
#         'n_samples': 24,
#         'mse': 3977111.4906462585,
#         'sl': {'y_pred': 13467,
#          'y_prob': 12296.782608695652,
#          'level': 8,
#          'split': [1, 76154.63636363637],
#          'n_samples': 21,
#          'mse': 4226852.05952381,
#          'sl': {'y_pred': 13379,
#           'y_prob': 6690.0,
#           'level': 9,
#           'split': [1, 73768.81818181818],
#           'n_samples': 2,
#           'mse': 770040.5,
#           'sl': {'y_pred': 14000,
#            'y_prob': 14000.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 12759,
#            'y_prob': 12759.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 13477,
#           'y_prob': 12193.666666666666,
#           'level': 9,
#           'split': [1, 81538.09090909091],
#           'n_samples': 19,
#           'mse': 4746498.328421052,
#           'sl': {'y_pred': 13830,
#            'y_prob': 11525.416666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 10,
#            'mse': 4350781.227160493},
#           'sr': {'y_pred': 13084,
#            'y_prob': 10705.727272727272,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'mse': 4770461.229166667}}},
#         'sr': {'y_pred': 12022,
#          'y_prob': 7213.8,
#          'level': 8,
#          'split': [1, 92703.0],
#          'n_samples': 3,
#          'mse': 195301.33333333334,
#          'sl': {'y_pred': 12040,
#           'y_prob': 6020.25,
#           'level': 9,
#           'split': [1, 92235.72727272728],
#           'n_samples': 2,
#           'mse': 583200.0,
#           'sl': {'y_pred': 11500,
#            'y_prob': 11500.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 12580,
#            'y_prob': 12580.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 11988,
#           'y_prob': 11988.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}},
#        'sr': {'y_pred': 10073,
#         'y_prob': 6044.4,
#         'level': 7,
#         'split': [1, 103972.0],
#         'n_samples': 3,
#         'mse': 2668412.3333333335,
#         'sl': {'y_pred': 10276,
#          'y_prob': 10276.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 9972,
#          'y_prob': 4986.5,
#          'level': 8,
#          'split': [1, 112340.72727272728],
#          'n_samples': 2,
#          'mse': 7821012.5,
#          'sl': {'y_pred': 11950,
#           'y_prob': 11950.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 7995,
#           'y_prob': 7995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}},
#       'sr': {'y_pred': 8873,
#        'y_prob': 5324.4,
#        'level': 6,
#        'split': [1, 124580.36363636363],
#        'n_samples': 3,
#        'mse': 963712.6666666666,
#        'sl': {'y_pred': 8997,
#         'y_prob': 8997.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0},
#        'sr': {'y_pred': 8812,
#         'y_prob': 4406.25,
#         'level': 7,
#         'split': [1, 128200.90909090909],
#         'n_samples': 2,
#         'mse': 2822688.0,
#         'sl': {'y_pred': 10000,
#          'y_prob': 10000.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 7624,
#          'y_prob': 7624.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}}}}}},
#    'sr': {'y_pred': 14625,
#     'y_prob': 14608.204640095182,
#     'level': 3,
#     'split': [1, 97521.81818181819],
#     'n_samples': 1679,
#     'mse': 12362672.998908157,
#     'sl': {'y_pred': 15310,
#      'y_prob': 15290.689136125655,
#      'level': 4,
#      'split': [1, 72944.81818181819],
#      'n_samples': 1526,
#      'mse': 7833496.190252389,
#      'sl': {'y_pred': 15757,
#       'y_prob': 15734.814254859612,
#       'level': 5,
#       'split': [1, 54248.0],
#       'n_samples': 1387,
#       'mse': 5939742.429447336,
#       'sl': {'y_pred': 16063,
#        'y_prob': 16037.832805071315,
#        'level': 6,
#        'split': [1, 47221.909090909096],
#        'n_samples': 1260,
#        'mse': 4821921.312064775,
#        'sl': {'y_pred': 16237,
#         'y_prob': 16208.86748038361,
#         'level': 7,
#         'split': [1, 43293.0],
#         'n_samples': 1145,
#         'mse': 4690788.0935653355,
#         'sl': {'y_pred': 16387,
#          'y_prob': 16355.62188099808,
#          'level': 8,
#          'split': [1, 40513.272727272735],
#          'n_samples': 1040,
#          'mse': 4705355.149156223,
#          'sl': {'y_pred': 16537,
#           'y_prob': 16502.258711721224,
#           'level': 9,
#           'split': [1, 37969.09090909091],
#           'n_samples': 945,
#           'mse': 4660617.783317265,
#           'sl': {'y_pred': 16675,
#            'y_prob': 16636.720092915213,
#            'level': 10,
#            'split': -1,
#            'n_samples': 859,
#            'mse': 4724731.837257179},
#           'sr': {'y_pred': 15156,
#            'y_prob': 14811.636363636364,
#            'level': 10,
#            'split': -1,
#            'n_samples': 86,
#            'mse': 1969609.0277624885}},
#          'sr': {'y_pred': 14893,
#           'y_prob': 14586.80412371134,
#           'level': 9,
#           'split': [1, 41598.181818181816],
#           'n_samples': 95,
#           'mse': 2640871.3535982813,
#           'sl': {'y_pred': 14866,
#            'y_prob': 14063.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 35,
#            'mse': 2374129.256905422},
#           'sr': {'y_pred': 14909,
#            'y_prob': 14428.870967741936,
#            'level': 10,
#            'split': -1,
#            'n_samples': 60,
#            'mse': 2794897.3457525396}}},
#         'sr': {'y_pred': 14752,
#          'y_prob': 14476.766355140187,
#          'level': 8,
#          'split': [1, 44418.181818181816],
#          'n_samples': 105,
#          'mse': 2097917.958712571,
#          'sl': {'y_pred': 14759,
#           'y_prob': 14021.525,
#           'level': 9,
#           'split': [1, 43804.63636363636],
#           'n_samples': 38,
#           'mse': 1816809.5789473683,
#           'sl': {'y_pred': 14754,
#            'y_prob': 13736.51724137931,
#            'level': 10,
#            'split': -1,
#            'n_samples': 27,
#            'mse': 1939961.814814815},
#           'sr': {'y_pred': 14772,
#            'y_prob': 12500.23076923077,
#            'level': 10,
#            'split': -1,
#            'n_samples': 11,
#            'mse': 1521388.5309090908}},
#          'sr': {'y_pred': 14748,
#           'y_prob': 14321.072463768116,
#           'level': 9,
#           'split': [1, 46834.0],
#           'n_samples': 67,
#           'mse': 2257599.260414594,
#           'sl': {'y_pred': 14767,
#            'y_prob': 14290.887096774193,
#            'level': 10,
#            'split': -1,
#            'n_samples': 60,
#            'mse': 2428150.7600137177},
#           'sr': {'y_pred': 14588,
#            'y_prob': 11346.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 769792.0625}}}},
#        'sr': {'y_pred': 14331,
#         'y_prob': 14086.965811965812,
#         'level': 7,
#         'split': [1, 48085.545454545456],
#         'n_samples': 115,
#         'mse': 2721374.799014098,
#         'sl': {'y_pred': 14336,
#          'y_prob': 13089.869565217392,
#          'level': 8,
#          'split': [1, 47854.181818181816],
#          'n_samples': 21,
#          'mse': 2003482.8457142853,
#          'sl': {'y_pred': 14367,
#           'y_prob': 12677.35294117647,
#           'level': 9,
#           'split': [1, 47572.09090909091],
#           'n_samples': 15,
#           'mse': 1699032.8,
#           'sl': {'y_pred': 14342,
#            'y_prob': 11155.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 1359958.205357143},
#           'sr': {'y_pred': 14390,
#            'y_prob': 11512.1,
#            'level': 10,
#            'split': -1,
#            'n_samples': 8,
#            'mse': 1996127.3061224488}},
#          'sr': {'y_pred': 14258,
#           'y_prob': 10694.125,
#           'level': 9,
#           'split': [1, 48068.27272727273],
#           'n_samples': 6,
#           'mse': 2939509.2933333335,
#           'sl': {'y_pred': 13828,
#            'y_prob': 9877.57142857143,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 2211679.7625},
#           'sr': {'y_pred': 16410,
#            'y_prob': 16410.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 14330,
#          'y_prob': 14032.385416666666,
#          'level': 8,
#          'split': [1, 51376.90909090909],
#          'n_samples': 94,
#          'mse': 2882909.253773099,
#          'sl': {'y_pred': 14362,
#           'y_prob': 13951.728571428572,
#           'level': 9,
#           'split': [1, 51153.90909090909],
#           'n_samples': 68,
#           'mse': 1771960.576655548,
#           'sl': {'y_pred': 14391,
#            'y_prob': 13934.682539682539,
#            'level': 10,
#            'split': -1,
#            'n_samples': 61,
#            'mse': 1891920.3665953123},
#           'sr': {'y_pred': 14105,
#            'y_prob': 10970.777777777777,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 680870.1428571428}},
#          'sr': {'y_pred': 14249,
#           'y_prob': 13231.75,
#           'level': 9,
#           'split': [1, 54154.90909090909],
#           'n_samples': 26,
#           'mse': 5933603.1840919005,
#           'sl': {'y_pred': 13855,
#            'y_prob': 12746.8,
#            'level': 10,
#            'split': -1,
#            'n_samples': 23,
#            'mse': 4373402.1920652175},
#           'sr': {'y_pred': 17273,
#            'y_prob': 10364.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 8186413.666666667}}}}},
#       'sr': {'y_pred': 12723,
#        'y_prob': 12526.457364341086,
#        'level': 6,
#        'split': [1, 71593.90909090909],
#        'n_samples': 127,
#        'mse': 6179523.417455605,
#        'sl': {'y_pred': 12772,
#         'y_prob': 12553.709401709402,
#         'level': 7,
#         'split': [1, 69058.0],
#         'n_samples': 115,
#         'mse': 6046506.613943916,
#         'sl': {'y_pred': 12956,
#          'y_prob': 12711.632075471698,
#          'level': 8,
#          'split': [1, 67767.0],
#          'n_samples': 104,
#          'mse': 5760388.628181914,
#          'sl': {'y_pred': 13033,
#           'y_prob': 12761.989583333334,
#           'level': 9,
#           'split': [1, 66042.72727272728],
#           'n_samples': 94,
#           'mse': 5525106.111462859,
#           'sl': {'y_pred': 13135,
#            'y_prob': 12833.919540229885,
#            'level': 10,
#            'split': -1,
#            'n_samples': 85,
#            'mse': 5301328.306789162},
#           'sr': {'y_pred': 12066,
#            'y_prob': 9872.818181818182,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'mse': 6704788.666666667}},
#          'sr': {'y_pred': 12228,
#           'y_prob': 10190.25,
#           'level': 9,
#           'split': [1, 68909.81818181818],
#           'n_samples': 10,
#           'mse': 7777008.4,
#           'sl': {'y_pred': 12824,
#            'y_prob': 9974.333333333334,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 5130966.359999999},
#           'sr': {'y_pred': 10838,
#            'y_prob': 6503.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 15149829.666666666}}},
#         'sr': {'y_pred': 11031,
#          'y_prob': 9334.76923076923,
#          'level': 8,
#          'split': [1, 71221.27272727272],
#          'n_samples': 11,
#          'mse': 5106504.476992144,
#          'sl': {'y_pred': 11007,
#           'y_prob': 9005.90909090909,
#           'level': 9,
#           'split': [1, 70483.18181818182],
#           'n_samples': 9,
#           'mse': 4039100.9166666665,
#           'sl': {'y_pred': 10981,
#            'y_prob': 8236.25,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 6174954.583333333},
#           'sr': {'y_pred': 11058,
#            'y_prob': 6635.2,
#            'level': 10,
#            'split': -1,
#            'n_samples': 3,
#            'mse': 250416.66666666666}},
#          'sr': {'y_pred': 11143,
#           'y_prob': 5572.0,
#           'level': 9,
#           'split': [1, 71376.09090909091],
#           'n_samples': 2,
#           'mse': 19788340.5,
#           'sl': {'y_pred': 7998,
#            'y_prob': 7998.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 14289,
#            'y_prob': 14289.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}},
#        'sr': {'y_pred': 12260,
#         'y_prob': 10509.285714285714,
#         'level': 7,
#         'split': [1, 72540.0],
#         'n_samples': 12,
#         'mse': 7523481.929012344,
#         'sl': {'y_pred': 12338,
#          'y_prob': 10094.90909090909,
#          'level': 8,
#          'split': [1, 72424.54545454546],
#          'n_samples': 9,
#          'mse': 7913650.83446712,
#          'sl': {'y_pred': 12346,
#           'y_prob': 9602.888888888889,
#           'level': 9,
#           'split': [1, 72287.09090909091],
#           'n_samples': 7,
#           'mse': 9586089.714285715,
#           'sl': {'y_pred': 12405,
#            'y_prob': 9303.875,
#            'level': 10,
#            'split': -1,
#            'n_samples': 6,
#            'mse': 11163854.666666666},
#           'sr': {'y_pred': 11995,
#            'y_prob': 11995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 12309,
#           'y_prob': 6154.75,
#           'level': 9,
#           'split': [1, 72521.27272727272],
#           'n_samples': 2,
#           'mse': 4141442.0,
#           'sl': {'y_pred': 10870,
#            'y_prob': 10870.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 13748,
#            'y_prob': 13748.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 12028,
#          'y_prob': 7217.4,
#          'level': 8,
#          'split': [1, 72774.27272727272],
#          'n_samples': 3,
#          'mse': 6865307.0,
#          'sl': {'y_pred': 11249,
#           'y_prob': 5624.75,
#           'level': 9,
#           'split': [1, 72560.09090909091],
#           'n_samples': 2,
#           'mse': 15125000.0,
#           'sl': {'y_pred': 8499,
#            'y_prob': 8499.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 13999,
#            'y_prob': 13999.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 13588,
#           'y_prob': 13588.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}}},
#      'sr': {'y_pred': 10852,
#       'y_prob': 10698.702127659575,
#       'level': 5,
#       'split': [1, 94637.90909090909],
#       'n_samples': 139,
#       'mse': 3618537.4394158144,
#       'sl': {'y_pred': 10967,
#        'y_prob': 10795.671875,
#        'level': 6,
#        'split': [1, 92618.81818181818],
#        'n_samples': 126,
#        'mse': 3667703.7456250284,
#        'sl': {'y_pred': 11023,
#         'y_prob': 10833.672413793103,
#         'level': 7,
#         'split': [1, 90777.36363636363],
#         'n_samples': 114,
#         'mse': 3441477.9113620846,
#         'sl': {'y_pred': 11097,
#          'y_prob': 10886.0,
#          'level': 8,
#          'split': [1, 88843.27272727274],
#          'n_samples': 103,
#          'mse': 3522725.2892718944,
#          'sl': {'y_pred': 11156,
#           'y_prob': 10921.873684210526,
#           'level': 9,
#           'split': [1, 86853.09090909091],
#           'n_samples': 93,
#           'mse': 3632674.0541108926,
#           'sl': {'y_pred': 11178,
#            'y_prob': 10918.17441860465,
#            'level': 10,
#            'split': -1,
#            'n_samples': 84,
#            'mse': 3199819.5746685797},
#           'sr': {'y_pred': 10957,
#            'y_prob': 8965.09090909091,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'mse': 7666498.888888889}},
# ...
#            'y_prob': 11970.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 12995,
#           'y_prob': 12995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}},
#         'sr': {'y_pred': 12799,
#          'y_prob': 12799.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 15991,
#         'y_prob': 15991.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0}}},
#      'sr': {'y_pred': 12521,
#       'y_prob': 9390.875,
#       'level': 5,
#       'split': [1, 85293.45454545454],
#       'n_samples': 6,
#       'mse': 4447266.160000001,
#       'sl': {'y_pred': 11886,
#        'y_prob': 8490.42857142857,
#        'level': 6,
#        'split': [1, 84680.63636363637],
#        'n_samples': 5,
#        'mse': 2598880.4625,
#        'sl': {'y_pred': 11484,
#         'y_prob': 7656.333333333333,
#         'level': 7,
#         'split': [1, 84001.27272727272],
#         'n_samples': 4,
#         'mse': 2485410.861111112,
#         'sl': {'y_pred': 10986,
#          'y_prob': 6592.2,
#          'level': 8,
#          'split': [1, 83466.36363636363],
#          'n_samples': 3,
#          'mse': 2247589.5833333335,
#          'sl': {'y_pred': 10482,
#           'y_prob': 5241.5,
#           'level': 9,
#           'split': [1, 83356.63636363637],
#           'n_samples': 2,
#           'mse': 4455112.5,
#           'sl': {'y_pred': 8990,
#            'y_prob': 8990.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 11975,
#            'y_prob': 11975.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 11995,
#           'y_prob': 11995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}},
#         'sr': {'y_pred': 12977,
#          'y_prob': 12977.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 13495,
#         'y_prob': 13495.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0}},
#       'sr': {'y_pred': 15694,
#        'y_prob': 15694.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0}}},
#     'sr': {'y_pred': 11881,
#      'y_prob': 8911.0,
#      'level': 4,
#      'split': [1, 87813.27272727272],
#      'n_samples': 6,
#      'mse': 974516.9933333333,
#      'sl': {'y_pred': 11967,
#       'y_prob': 8548.285714285714,
#       'level': 5,
#       'split': [1, 87349.18181818182],
#       'n_samples': 5,
#       'mse': 1188698.8625,
#       'sl': {'y_pred': 12237,
#        'y_prob': 8158.333333333333,
#        'level': 6,
#        'split': [1, 86582.0],
#        'n_samples': 4,
#        'mse': 1279007.75,
#        'sl': {'y_pred': 12735,
#         'y_prob': 6368.0,
#         'level': 7,
#         'split': [1, 85741.54545454546],
#         'n_samples': 2,
#         'mse': 4.5,
#         'sl': {'y_pred': 12737,
#          'y_prob': 12737.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 12734,
#          'y_prob': 12734.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 11739,
#         'y_prob': 5869.75,
#         'level': 7,
#         'split': [1, 86866.81818181818],
#         'n_samples': 2,
#         'mse': 3130002.0,
#         'sl': {'y_pred': 12990,
#          'y_prob': 12990.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 10488,
#          'y_prob': 10488.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}}},
#       'sr': {'y_pred': 10888,
#        'y_prob': 10888.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0}},
#      'sr': {'y_pred': 11450,
#       'y_prob': 11450.0,
#       'level': 5,
#       'split': -1,
#       'n_samples': 1,
#       'mse': 0}}}},
#   'sr': {'y_pred': 9873,
#    'y_prob': 9606.27027027027,
#    'level': 2,
#    'split': [1, 152438.54545454547],
#    'n_samples': 72,
#    'mse': 7214680.718852729,
#    'sl': {'y_pred': 10229,
#     'y_prob': 9923.89552238806,
#     'level': 3,
#     'split': [1, 135468.63636363638],
#     'n_samples': 65,
#     'mse': 6535864.7430004645,
#     'sl': {'y_pred': 10559,
#      'y_prob': 10212.852459016394,
#      'level': 4,
#      'split': [1, 124591.27272727275],
#      'n_samples': 59,
#      'mse': 5808728.894938182,
#      'sl': {'y_pred': 10808,
#       'y_prob': 10415.690909090908,
#       'level': 5,
#       'split': [1, 116576.90909090909],
#       'n_samples': 53,
#       'mse': 5309041.47431866,
#       'sl': {'y_pred': 10918,
#        'y_prob': 10482.1,
#        'level': 6,
#        'split': [1, 105884.27272727272],
#        'n_samples': 48,
#        'mse': 5586930.230816327,
#        'sl': {'y_pred': 11040,
#         'y_prob': 10443.621621621622,
#         'level': 7,
#         'split': [1, 101662.36363636363],
#         'n_samples': 35,
#         'mse': 6298336.535900103,
#         'sl': {'y_pred': 11156,
#          'y_prob': 10480.575757575758,
#          'level': 8,
#          'split': [1, 99783.27272727272],
#          'n_samples': 31,
#          'mse': 5802202.477729032,
#          'sl': {'y_pred': 11255,
#           'y_prob': 10421.37037037037,
#           'level': 9,
#           'split': [1, 95762.63636363637],
#           'n_samples': 25,
#           'mse': 5567721.956049382,
#           'sl': {'y_pred': 11211,
#            'y_prob': 10090.15,
#            'level': 10,
#            'split': -1,
#            'n_samples': 18,
#            'mse': 5507194.014464167},
#           'sr': {'y_pred': 11367,
#            'y_prob': 8841.666666666666,
#            'level': 10,
#            'split': -1,
#            'n_samples': 7,
#            'mse': 5752276.411428571}},
#          'sr': {'y_pred': 10747,
#           'y_prob': 8060.375,
#           'level': 9,
#           'split': [1, 99918.27272727272],
#           'n_samples': 6,
#           'mse': 7087109.0,
#           'sl': {'y_pred': 10000,
#            'y_prob': 10000.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 10896,
#            'y_prob': 7783.285714285715,
#            'level': 10,
#            'split': -1,
#            'n_samples': 5,
#            'mse': 8699198.65}}},
#         'sr': {'y_pred': 10138,
#          'y_prob': 6759.333333333333,
#          'level': 8,
#          'split': [1, 103789.45454545454],
#          'n_samples': 4,
#          'mse': 9308981.25,
#          'sl': {'y_pred': 10495,
#           'y_prob': 5247.75,
#           'level': 9,
#           'split': [1, 101867.72727272728],
#           'n_samples': 2,
#           'mse': 4500000.0,
#           'sl': {'y_pred': 11995,
#            'y_prob': 11995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 8995,
#            'y_prob': 8995.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 9782,
#           'y_prob': 4891.5,
#           'level': 9,
#           'split': [1, 104929.18181818182],
#           'n_samples': 2,
#           'mse': 31720612.5,
#           'sl': {'y_pred': 13765,
#            'y_prob': 13765.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 5800,
#            'y_prob': 5800.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}}},
#        'sr': {'y_pred': 10591,
#         'y_prob': 9179.466666666667,
#         'level': 7,
#         'split': [1, 115140.09090909091],
#         'n_samples': 13,
#         'mse': 3508383.0712015256,
#         'sl': {'y_pred': 10633,
#          'y_prob': 8997.307692307691,
#          'level': 8,
#          'split': [1, 113469.18181818182],
#          'n_samples': 11,
#          'mse': 4071011.544545454,
#          'sl': {'y_pred': 10738,
#           'y_prob': 8949.0,
#           'level': 9,
#           'split': [1, 111655.18181818182],
#           'n_samples': 10,
#           'mse': 4362254.179012345,
#           'sl': {'y_pred': 10876,
#            'y_prob': 8899.363636363636,
#            'level': 10,
#            'split': -1,
#            'n_samples': 9,
#            'mse': 4637590.222222222},
#           'sr': {'y_pred': 9495,
#            'y_prob': 9495.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}},
#          'sr': {'y_pred': 9577,
#           'y_prob': 9577.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}},
#         'sr': {'y_pred': 10363,
#          'y_prob': 5182.0,
#          'level': 8,
#          'split': [1, 115335.72727272728],
#          'n_samples': 2,
#          'mse': 805180.5,
#          'sl': {'y_pred': 9729,
#           'y_prob': 9729.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 10998,
#           'y_prob': 10998.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}}},
#       'sr': {'y_pred': 9751,
#        'y_prob': 6965.571428571428,
#        'level': 6,
#        'split': [1, 121010.18181818182],
#        'n_samples': 5,
#        'mse': 1425395.0625,
#        'sl': {'y_pred': 9820,
#         'y_prob': 6547.0,
#         'level': 7,
#         'split': [1, 119654.72727272728],
#         'n_samples': 4,
#         'mse': 1763755.527777778,
#         'sl': {'y_pred': 9927,
#          'y_prob': 5956.6,
#          'level': 8,
#          'split': [1, 117159.27272727272],
#          'n_samples': 3,
#          'mse': 3430429.6666666665,
#          'sl': {'y_pred': 10995,
#           'y_prob': 10995.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 9393,
#           'y_prob': 4697.0,
#           'level': 9,
#           'split': [1, 118617.09090909091],
#           'n_samples': 2,
#           'mse': 5161684.5,
#           'sl': {'y_pred': 11000,
#            'y_prob': 11000.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0},
#           'sr': {'y_pred': 7787,
#            'y_prob': 7787.0,
#            'level': 10,
#            'split': -1,
#            'n_samples': 1,
#            'mse': 0}}},
#         'sr': {'y_pred': 9499,
#          'y_prob': 9499.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 9477,
#         'y_prob': 9477.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0}}},
#      'sr': {'y_pred': 8353,
#       'y_prob': 6265.25,
#       'level': 5,
#       'split': [1, 126080.36363636363],
#       'n_samples': 6,
#       'mse': 4309309.833333333,
#       'sl': {'y_pred': 8441,
#        'y_prob': 8441.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0},
#       'sr': {'y_pred': 8336,
#        'y_prob': 5954.428571428572,
#        'level': 6,
#        'split': [1, 129415.18181818182],
#        'n_samples': 5,
#        'mse': 5374515.8,
#        'sl': {'y_pred': 8799,
#         'y_prob': 5279.6,
#         'level': 7,
#         'split': [1, 126969.09090909091],
#         'n_samples': 3,
#         'mse': 4745001.666666667,
#         'sl': {'y_pred': 9410,
#          'y_prob': 9410.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 8493,
#          'y_prob': 4247.0,
#          'level': 8,
#          'split': [1, 127774.81818181818],
#          'n_samples': 2,
#          'mse': 12555060.5,
#          'sl': {'y_pred': 5988,
#           'y_prob': 5988.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 10999,
#           'y_prob': 10999.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}}},
#        'sr': {'y_pred': 7641,
#         'y_prob': 3821.0,
#         'level': 7,
#         'split': [1, 131124.81818181818],
#         'n_samples': 2,
#         'mse': 11077924.5,
#         'sl': {'y_pred': 9995,
#          'y_prob': 9995.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 5288,
#          'y_prob': 5288.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}}}}},
#     'sr': {'y_pred': 6986,
#      'y_prob': 5239.75,
#      'level': 4,
#      'split': [1, 150655.0909090909],
#      'n_samples': 6,
#      'mse': 1576625.4599999997,
#      'sl': {'y_pred': 7193,
#       'y_prob': 5138.285714285715,
#       'level': 5,
#       'split': [1, 145995.9090909091],
#       'n_samples': 5,
#       'mse': 1673102.2,
#       'sl': {'y_pred': 7494,
#        'y_prob': 4996.166666666667,
#        'level': 6,
#        'split': [1, 141362.81818181818],
#        'n_samples': 4,
#        'mse': 1553850.5,
#        'sl': {'y_pred': 7659,
#         'y_prob': 4595.6,
#         'level': 7,
#         'split': [1, 138167.0],
#         'n_samples': 3,
#         'mse': 2858790.9166666665,
#         'sl': {'y_pred': 6693,
#          'y_prob': 3347.0,
#          'level': 8,
#          'split': [1, 137309.27272727274],
#          'n_samples': 2,
#          'mse': 186660.5,
#          'sl': {'y_pred': 6388,
#           'y_prob': 6388.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0},
#          'sr': {'y_pred': 6999,
#           'y_prob': 6999.0,
#           'level': 9,
#           'split': -1,
#           'n_samples': 1,
#           'mse': 0}},
#         'sr': {'y_pred': 9590,
#          'y_prob': 9590.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 6999,
#         'y_prob': 6999.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0}},
#       'sr': {'y_pred': 5991,
#        'y_prob': 5991.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0}},
#      'sr': {'y_pred': 5950,
#       'y_prob': 5950.0,
#       'level': 5,
#       'split': -1,
#       'n_samples': 1,
#       'mse': 0}}},
#    'sr': {'y_pred': 6566,
#     'y_prob': 5107.111111111111,
#     'level': 3,
#     'split': [1, 175469.63636363635],
#     'n_samples': 7,
#     'mse': 1116467.5714285714,
#     'sl': {'y_pred': 6648,
#      'y_prob': 4986.125,
#      'level': 4,
#      'split': [1, 165821.27272727274],
#      'n_samples': 6,
#      'mse': 1278976.25,
#      'sl': {'y_pred': 6824,
#       'y_prob': 4549.833333333333,
#       'level': 5,
#       'split': [1, 153762.27272727274],
#       'n_samples': 4,
#       'mse': 1602701.5,
#       'sl': {'y_pred': 6891,
#        'y_prob': 6891.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0},
#       'sr': {'y_pred': 6802,
#        'y_prob': 4081.6,
#        'level': 6,
#        'split': [1, 160066.9090909091],
#        'n_samples': 3,
#        'mse': 2310691.5833333335,
#        'sl': {'y_pred': 7228,
#         'y_prob': 3614.5,
#         'level': 7,
#         'split': [1, 154982.9090909091],
#         'n_samples': 2,
#         'mse': 5297512.5,
#         'sl': {'y_pred': 5601,
#          'y_prob': 5601.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0},
#         'sr': {'y_pred': 8856,
#          'y_prob': 8856.0,
#          'level': 8,
#          'split': -1,
#          'n_samples': 1,
#          'mse': 0}},
#        'sr': {'y_pred': 5950,
#         'y_prob': 5950.0,
#         'level': 7,
#         'split': -1,
#         'n_samples': 1,
#         'mse': 0}}},
#      'sr': {'y_pred': 6295,
#       'y_prob': 3147.75,
#       'level': 5,
#       'split': [1, 166956.45454545456],
#       'n_samples': 2,
#       'mse': 720000.0,
#       'sl': {'y_pred': 6895,
#        'y_prob': 6895.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0},
#       'sr': {'y_pred': 5695,
#        'y_prob': 5695.0,
#        'level': 6,
#        'split': -1,
#        'n_samples': 1,
#        'mse': 0}}},
#     'sr': {'y_pred': 6075,
#      'y_prob': 6075.0,
#      'level': 4,
#      'split': -1,
#      'n_samples': 1,
#      'mse': 0}}}}}

# %%
y_predTreeManual = tree_predict(X_test, tree)
y_predTreeManual
# Out:
# array([13135.,  8622., 17644., ..., 17644., 10882., 11367.])

# %%
from sklearn.metrics import mean_squared_error
rmse_TreeManual = mean_squared_error(y_test, y_predTreeManual, squared=False)
rmse_TreeManual
# Out:
# 2156.298895352172

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_TreeManual = mae(y_test, y_predTreeManual)
mae_TreeManual
# Out:
# 1586.6264434180139

# %% [markdown]
# ### Punto 2 - Bagging manual
#
# En la celda 2 creen un modelo bagging **manualmente** con 10 árboles de clasificación y comenten sobre el desempeño del modelo.

# %%
# Celda 2
# Creación de 10 muestras de bootstrap para los 10 árboles
np.random.seed(123)

n_samples = X_train.shape[0]
n_B = 10

samples = [np.random.choice(a=n_samples, size=n_samples, replace=True) for _ in range(1, n_B +1 )]

from sklearn.tree import DecisionTreeRegressor
treereg = DecisionTreeRegressor(max_depth=None, random_state=123)
y_pred = pd.DataFrame(index=y_test.index, columns=[list(range(n_B))])

for i, sample in enumerate(samples):
    X2_train = X_train.iloc[sample,:]
    y2_train = y_train.iloc[sample]
    treereg.fit(X2_train, y2_train)
    y_pred.iloc[:,i] = treereg.predict(X_test)
    
y_pred
# Out:
#               0        1        2        3        4        5        6  \
# 257343  14980.0  13993.0  13649.0  13649.0  11788.0  13649.0  13993.0
# 326011   6492.0   5995.0   5995.0   6987.0   5995.0   5995.0   5995.0
# 242354  16491.0  16995.0  16491.0  15997.0  15997.0  16491.0  17591.0
# 266376  21990.0  21990.0  22500.0  21990.0  15900.0  21990.0  22500.0
# 396954  15988.0  16951.0  15988.0  15988.0  15988.0  17900.0  16951.0
# ...         ...      ...      ...      ...      ...      ...      ...
# 144298  13836.0  14800.0  14800.0  14800.0  14800.0  14681.0  14800.0
# 364521  15999.0  14995.0  15999.0  16900.0  15999.0  15999.0  17300.0
# 120072  23533.0  23533.0  20000.0  17700.0  17700.0  23533.0  17700.0
# 99878   12989.0  12995.0  12989.0  12995.0  12991.0  12991.0  10995.0
# 387162  10991.0  11314.0  12999.0  12995.0   9995.0  11995.0  11985.0
#
#               7        8        9
# 257343  13990.0  13990.0  13993.0
# 326011   6987.0   5995.0   5995.0
# 242354  16995.0  17404.0  16491.0
# 266376  21990.0  15813.0  21990.0
# 396954  16951.0  15988.0  15988.0
# ...         ...      ...      ...
# 144298  14800.0  13836.0  13836.0
# 364521  15999.0  16900.0  15000.0
# 120072  23533.0  23533.0  20000.0
# 99878   12991.0  12991.0  12893.0
# 387162  10991.0  11314.0  14995.0
#
# [3464 rows x 10 columns]

# %%
# Desempeño de cada árbol
for i in range(n_B):
    print('Árbol ', i, 'tiene un rmse: ', (mean_squared_error(y_pred.iloc[:,i], y_test, squared=False)))
# Out:
# Árbol  0 tiene un rmse:  2141.613353645869
# Árbol  1 tiene un rmse:  2136.3519863123465
# Árbol  2 tiene un rmse:  2122.718759132052
# Árbol  3 tiene un rmse:  2087.278992468617
# Árbol  4 tiene un rmse:  2168.518742842026
# Árbol  5 tiene un rmse:  2113.8811455834793
# Árbol  6 tiene un rmse:  2127.933470769012
# Árbol  7 tiene un rmse:  2184.414847251443
# Árbol  8 tiene un rmse:  2138.1071697514985
# Árbol  9 tiene un rmse:  2132.097520859104

# %%
#Promediamos las predicciones
y_predBaggingManual = y_pred.mean(axis=1)

# %%
rmse_BaggingManual = mean_squared_error(y_test, y_predBaggingManual, squared=False)
rmse_BaggingManual
# Out:
# 1796.4355868399332

# %%
mae_BaggingManual = mae(y_test, y_predBaggingManual)
mae_BaggingManual
# Out:
# 1340.0160739030025

# %% [markdown]
# **DESEMPEÑO DEL MODELO**
#
# Encontramos que en general en comparación con el modelo de un solo árbol de decisión realizando un ensamblaje por Bagging de 10 árboles mejora notablemente el desempeño de la predicción, donde vemos que la comparación del rmse es de 1796 para el Bagging y 2156 para un modelo con solo un árbol.
#
# Por otro lado el mean absolute error mejor de 1586 de un solo árbol de decisión a 1340 para el modelo de bagging, para este caso se demuestra como este ensamble de 10 árboles mejora en rendimiento a los resultados de un solo árbol.

# %% [markdown]
# ### Punto 3 - Bagging con librería
#
# En la celda 3, con la librería sklearn, entrenen un modelo bagging con 10 árboles de clasificación y el parámetro `max_features` igual a `log(n_features)` y comenten sobre el desempeño del modelo.

# %%
# Celda 3

# %% [markdown]
# ### Punto 4 - Random forest con librería
#
# En la celda 4, usando la librería sklearn entrenen un modelo de Randon Forest para clasificación  y comenten sobre el desempeño del modelo.

# %%
# Celda 4

# %% [markdown]
# ### Punto 5 - Calibración de parámetros Random forest
#
# En la celda 5, calibren los parámetros max_depth, max_features y n_estimators del modelo de Randon Forest para clasificación, comenten sobre el desempeño del modelo y describan cómo cada parámetro afecta el desempeño del modelo.

# %%
# Celda 5

# %% [markdown]
# ### Punto 6 - XGBoost con librería
#
# En la celda 6 implementen un modelo XGBoost de clasificación con la librería sklearn y comenten sobre el desempeño del modelo.

# %%
# Celda 6

# %% [markdown]
# ### Punto 7 - Calibración de parámetros XGBoost
#
# En la celda 7 calibren los parámetros learning rate, gamma y colsample_bytree del modelo XGBoost para clasificación, comenten sobre el desempeño del modelo y describan cómo cada parámetro afecta el desempeño del modelo.

# %%
# Celda 7

# %% [markdown]
# ### Punto 8 - Comparación y análisis de resultados
# En la celda 8 comparen los resultados obtenidos de los diferentes modelos (random forest y XGBoost) y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 8
